# %%
from flask import Flask , request , jsonify
import pyodbc
import pymongo
from pymongo import MongoClient
from bson.objectid import ObjectId
import threading
import time
from datetime import datetime, date
from decimal import Decimal
import requests

# %%
app = Flask(__name__)

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["MyDatabase"]

# Define collections
source_coll = db["RetailCustomerData_Coll"]
target_coll = db["SalesCollection1"]

# %%
# ============================
# 1- API to generate SalesCollection from original data
# ============================
@app.route("/generate_sales_collection", methods=["POST"])
def generate_sales_collection():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "CustomerID": "$CustomerID",
                        "CustomerName": "$CustomerName",
                        "PreferredBranch": "$BranchName"
                    },
                    "TotalSpent": {"$sum": "$TotalPrice"},
                    "TotalOrders": {"$addToSet": "$SaleID"},
                    "TopProducts": {
                        "$push": {
                            "ProductName": "$ProductName",
                            "Quantity": "$Quantity"
                        }
                    },
                    "MonthlyPurchases": {
                        "$push": {
                            "Month": {
                                "$dateToString": {"format": "%Y-%m", "date": "$SaleDate"}
                            },
                            "Amount": "$TotalPrice"
                        }
                    }
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "CustomerID": "$_id.CustomerID",
                    "CustomerName": "$_id.CustomerName",
                    "PreferredBranch": "$_id.PreferredBranch",
                    "TotalSpent": 1,
                    "TotalOrders": {"$size": "$TotalOrders"},
                    "TopProducts": 1,
                    "MonthlyPurchases": {
                        "$arrayToObject": {
                            "$map": {
                                "input": "$MonthlyPurchases",
                                "as": "mp",
                                "in": {"k": "$$mp.Month", "v": "$$mp.Amount"}
                            }
                        }
                    }
                }
            },
            {"$out": "SalesCollection1"}
        ]

        # Run the aggregation
        source_coll.aggregate(pipeline)

        return jsonify({"message": "SalesCollection generated successfully ✅"}), 201
    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# 2- API to fetch data from SalesCollection
# ============================
@app.route("/get_sales_collection", methods=["GET"])
def get_sales_collection():
    try:
        data = list(target_coll.find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# ============================
# API: Generate Top Customers Collection
# ============================
@app.route("/generate_top_customers", methods=["POST"])
def generate_top_customers():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "CustomerID": "$CustomerID",
                        "CustomerName": "$CustomerName"
                    },
                    "TotalSpent": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "CustomerID": "$_id.CustomerID",
                    "CustomerName": "$_id.CustomerName",
                    "TotalSpent": 1
                }
            },
            {"$sort": {"TotalSpent": -1}},   # Sort descending
            {"$limit": 5},                   # Top 5
            {"$out": "TopCustomers"}         # Save result in new collection
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "TopCustomers collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Top Customers Collection
# ============================
@app.route("/get_top_customers", methods=["GET"])
def get_top_customers():
    try:
        data = list(target_coll.find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500
    


    # ============================
# API: Generate Best-Selling Products Collection
# ============================
@app.route("/generate_best_selling_products", methods=["POST"])
def generate_best_selling_products():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": "$ProductName",
                    "TotalQuantity": {"$sum": "$Quantity"},
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "ProductName": "$_id",
                    "TotalQuantity": 1,
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"TotalQuantity": -1}},   # Sort by quantity sold (descending)
            {"$limit": 10},                     # Top 10 best-selling products
            {"$out": "BestSellingProducts"}     # Save in new collection
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "BestSellingProducts collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Best-Selling Products Collection
# ============================
@app.route("/get_best_selling_products", methods=["GET"])
def get_best_selling_products():
    try:
        data = list(db["BestSellingProducts"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500
    


    # ============================
# API: Generate Best-Selling Products by Branch Collection
# ============================
@app.route("/generate_best_selling_products_by_branch", methods=["POST"])
def generate_best_selling_products_by_branch():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "BranchName": "$BranchName",
                        "ProductName": "$ProductName"
                    },
                    "TotalQuantity": {"$sum": "$Quantity"},
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "BranchName": "$_id.BranchName",
                    "ProductName": "$_id.ProductName",
                    "TotalQuantity": 1,
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"BranchName": 1, "TotalQuantity": -1}},  # Sort by branch then quantity
            {"$out": "BestSellingProductsByBranch"}             # Save in new collection
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "BestSellingProductsByBranch collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Best-Selling Products by Branch Collection
# ============================
@app.route("/get_best_selling_products_by_branch", methods=["GET"])
def get_best_selling_products_by_branch():
    try:
        data = list(db["BestSellingProductsByBranch"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500
    

    # ============================
# API: Generate Branch Revenue Comparison Collection
# ============================
@app.route("/generate_branch_revenue_comparison", methods=["POST"])
def generate_branch_revenue_comparison():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": "$BranchName",
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "BranchName": "$_id",
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"TotalRevenue": -1}},  # ترتيب تنازلي حسب الإيراد
            {"$out": "BranchRevenueComparison"}  # تخزين النتيجة في كوليكشن جديد
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "BranchRevenueComparison collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Branch Revenue Comparison Collection
# ============================
@app.route("/get_branch_revenue_comparison", methods=["GET"])
def get_branch_revenue_comparison():
    try:
        data = list(db["BranchRevenueComparison"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500
    


# ============================
# API: Generate Monthly Sales Trends Collection
# ============================
@app.route("/generate_monthly_sales_trends", methods=["POST"])
def generate_monthly_sales_trends():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "Month": {"$dateToString": {"format": "%Y-%m", "date": "$SaleDate"}}
                    },
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "Month": "$_id.Month",
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"Month": 1}},  # ترتيب تصاعدي بالشهور
            {"$out": "MonthlySalesTrends"}  # حفظ النتيجة في كوليكشن جديد
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "MonthlySalesTrends collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Monthly Sales Trends Collection
# ============================
@app.route("/get_monthly_sales_trends", methods=["GET"])
def get_monthly_sales_trends():
    try:
        data = list(db["MonthlySalesTrends"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500
    



# ============================
# API: Generate Seasonal Product Demand Collection
# ============================
@app.route("/generate_seasonal_product_demand", methods=["POST"])
def generate_seasonal_product_demand():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "Month": {"$dateToString": {"format": "%Y-%m", "date": "$SaleDate"}},
                        "ProductName": "$ProductName"
                    },
                    "TotalQuantity": {"$sum": "$Quantity"},
                    "TotalRevenue": {"$sum": "$TotalPrice"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "Month": "$_id.Month",
                    "ProductName": "$_id.ProductName",
                    "TotalQuantity": 1,
                    "TotalRevenue": 1
                }
            },
            {"$sort": {"Month": 1, "TotalQuantity": -1}},
            {"$out": "SeasonalProductDemand"}
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "SeasonalProductDemand collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Seasonal Product Demand Collection
# ============================
@app.route("/get_seasonal_product_demand", methods=["GET"])
def get_seasonal_product_demand():
    try:
        data = list(db["SeasonalProductDemand"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500
    


# ============================
# API: Generate Stock Planning Collection
# ============================
@app.route("/generate_stock_planning", methods=["POST"])
def generate_stock_planning():
    try:
        pipeline = [
            {
                "$group": {
                    "_id": {
                        "BranchName": "$BranchName",
                        "ProductName": "$ProductName"
                    },
                    "TotalQuantity": {"$sum": "$Quantity"}
                }
            },
            {
                "$project": {
                    "_id": 0,
                    "BranchName": "$_id.BranchName",
                    "ProductName": "$_id.ProductName",
                    "TotalQuantity": 1
                }
            },
            {"$sort": {"BranchName": 1, "TotalQuantity": -1}},
            {"$out": "StockPlanning"}
        ]

        source_coll.aggregate(pipeline)
        return jsonify({"message": "StockPlanning collection created successfully ✅"}), 201

    except Exception as e:
        return jsonify({"error": str(e)}), 500


# ============================
# API: Fetch Stock Planning Collection
# ============================
@app.route("/get_stock_planning", methods=["GET"])
def get_stock_planning():
    try:
        data = list(db["StockPlanning"].find({}, {"_id": 0}))
        return jsonify(data), 200
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
# Code to Run the Flask API 
def run_flask():
    app.run(port=5000, debug=False, use_reloader=False)

# Code to Run the Flask API in a separate thread in the background  
threading.Thread(target=run_flask).start()
time.sleep(1)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "POST /generate_sales_collection HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "POST /generate_top_customers HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "POST /generate_best_selling_products_by_branch HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "POST /generate_branch_revenue_comparison HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "POST /generate_monthly_sales_trends HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "POST /generate_seasonal_product_demand HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "POST /generate_stock_planning HTTP/1.1" 201 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "GET /get_sales_collection HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Aug/2025 00:11:07] "GET /get_top_customers HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Aug/2025 00:11:08] "GET /get_best_selling_products HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Aug/2025 00:11:08] "GET /get_best_selling_products_by_branch HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Aug/2025 00:11:08] "GET /get_branch_revenue_comparison HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Aug/2025 00:11:08] "GET /get_monthly_sales_trends HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Aug/2025 00:11:08] "GET /get_seasonal_product_demand HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Aug/2025 00:11:08] "GET /get_stock_planning HTTP/1.1" 200 -

# %%
import requests

url = "http://127.0.0.1:5000/generate_sales_collection"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())

url = "http://127.0.0.1:5000/generate_top_customers"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())

url = "http://127.0.0.1:5000/generate_best_selling_products_by_branch"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/generate_branch_revenue_comparison"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/generate_monthly_sales_trends"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/generate_seasonal_product_demand"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/generate_stock_planning"

response = requests.post(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'message': 'SalesCollection generated successfully ✅'}
# Status Code: 201
# Response: {'message': 'TopCustomers collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'BestSellingProductsByBranch collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'BranchRevenueComparison collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'MonthlySalesTrends collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'SeasonalProductDemand collection created successfully ✅'}
# Status Code: 201
# Response: {'message': 'StockPlanning collection created successfully ✅'}

# %%
import requests

url = "http://127.0.0.1:5000/get_sales_collection"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())

url = "http://127.0.0.1:5000/get_top_customers"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())

url = "http://127.0.0.1:5000/get_best_selling_products"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())

url = "http://127.0.0.1:5000/get_best_selling_products_by_branch"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())

url = "http://127.0.0.1:5000/get_branch_revenue_comparison"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/get_monthly_sales_trends"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/get_seasonal_product_demand"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())


url = "http://127.0.0.1:5000/get_stock_planning"

response = requests.get(url)

print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 200
# Response: [{'CustomerID': 636, 'CustomerName': 'Antonio Jackson', 'MonthlyPurchases': {'2020-03': 16185.3}, 'PreferredBranch': 'Nguyen-Lopez', 'TopProducts': [{'ProductName': 'Evidence', 'Quantity': 20}, {'ProductName': 'Determine', 'Quantity': 1}, {'ProductName': 'List', 'Quantity': 15}], 'TotalOrders': 1, 'TotalSpent': 21878.59}, {'CustomerID': 653, 'CustomerName': 'Gerald Reynolds', 'MonthlyPurchases': {'2024-11': 15057.46}, 'PreferredBranch': 'Garcia, Patterson and Alvarado', 'TopProducts': [{'ProductName': 'Yourself', 'Quantity': 20}, {'ProductName': 'Remain', 'Quantity': 3}, {'ProductName': 'Newspaper', 'Quantity': 11}], 'TotalOrders': 1, 'TotalSpent': 31849.559999999998}, {'CustomerID': 945, 'CustomerName': 'Jessica Mays', 'MonthlyPurchases': {'2024-12': 5982.54}, 'PreferredBranch': 'Schaefer-Dean', 'TopProducts': [{'ProductName': 'Particularly', 'Quantity': 3}], 'TotalOrders': 1, 'TotalSpent': 5982.54}, {'CustomerID': 901, 'CustomerName': 'Tammy Brown', 'MonthlyPurchases': {'2021-06': 2534.0}, 'PreferredBranch': 'Johnson, Smith and Aguilar', 'TopProducts': [{'ProductName': 'Foreign', 'Quantity': 7}], 'TotalOrders': 1, 'TotalSpent': 2534.0}, {'CustomerID': 25, 'CustomerName': 'Phillip Holmes', 'MonthlyPurchases': {'2021-05': 2243.88}, 'PreferredBranch': 'Martinez, Kane and Fleming', 'TopProducts': [{'ProductName': 'Everything', 'Quantity': 9}], 'TotalOrders': 1, 'TotalSpent': 2243.88}, {'CustomerID': 450, 'CustomerName': 'Patrick Salazar', 'MonthlyPurchases': {'2024-03': 18327.01}, 'PreferredBranch': 'Schmidt-Holt', 'TopProducts': [{'ProductName': 'Outside', 'Quantity': 11}, {'ProductName': 'Deep', 'Quantity': 13}], 'TotalOrders': 1, 'TotalSpent': 23628.239999999998}, {'CustomerID': 915, 'CustomerName': 'Dave White', 'MonthlyPurchases': {'2020-08': 5232.08}, 'PreferredBranch': 'Hayes-Tanner', 'TopProducts': [{'ProductName': 'Base', 'Quantity': 5}, {'ProductName': 'Why', 'Quantity': 5}, {'ProductName': 'Travel', 'Quantity': 14}], 'TotalOrders': 1, 'TotalSpent': 14674.38}, {'CustomerID': 430, 'CustomerName': 'Amanda Huber', 'MonthlyPurchases': {'2020-06': 12727.1}, 'PreferredBranch': 'Thornton LLC', 'TopProducts': [{'ProductName': 'Letter', 'Quantity': 10}], 'TotalOrders': 1, 'TotalSpent': 12727.1}, {'CustomerID': 533, 'CustomerName': 'Ryan Hunter', 'MonthlyPurchases': {'2022-07': 15051.6}, 'PreferredBranch': 'Nguyen-Lopez', 'TopProducts': [{'ProductName': 'Ten', 'Quantity': 11}, {'ProductName': 'Market', 'Quantity': 9}], 'TotalOrders': 1, 'TotalSpent': 23562.08}, {'CustomerID': 754, 'CustomerName': 'Laura Fischer', 'MonthlyPurchases': {'2022-11': 617.43}, 'PreferredBranch': 'Price-Norman', 'TopProducts': [{'ProductName': 'Message', 'Quantity': 1}], 'TotalOrders': 1, 'TotalSpent': 617.43}, {'CustomerID': 600, 'CustomerName': 'Jennifer Hamilton', 'MonthlyPurchases': {'2020-09': 4465.68}, 'PreferredBranch': 'Mason-Hawkins', 'TopProducts': [{'ProductName': 'Himself', 'Quantity': 4}], 'TotalOrders': 1, 'TotalSpent': 4465.68}, {'CustomerID': 338, 'CustomerName': 'Valerie Martin', 'MonthlyPurchases': {'2021-04': 4353.15}, 'PreferredBranch': 'Johnson, Smith and Aguilar', 'TopProducts': [{'ProductName': 'Where', 'Quantity': 8}, {'ProductName': 'Probably', 'Quantity': 9}, {'ProductName': 'Open', 'Quantity': 5}], 'TotalOrders': 1, 'TotalSpent': 15048.07}, {'CustomerID': 653, 'CustomerName': 'Gerald Reynolds', 'MonthlyPurchases': {'2025-01': 9595.0}, 'PreferredBranch': 'Mayo Inc', 'TopProducts': [{'ProductName': 'Take', 'Quantity': 19}], 'TotalOrders': 1, 'TotalSpent': 9595.0}, {'CustomerID': 972, 'CustomerName': 'Andrew Willis', 'MonthlyPurchases': {'2022-03': 1228.14}, 'PreferredBranch': 'Montgomery-Foley', 'TopProducts': [{'ProductName': 'Owner', 'Quantity': 13}, {'ProductName': 'When', 'Quantity': 1}], 'TotalOrders': 1, 'TotalSpent': 2418.42}, {'CustomerID': 396, 'CustomerName': 'Maria Pope', 'MonthlyPurchases': {'2025-01': 3991.44}, 'PreferredBranch': 'Krause, Haas and Lozano', 'TopProducts': [{'ProductName': 'Team', 'Quantity' ...
# Status Code: 200
# Response: [{'CustomerID': 636, 'CustomerName': 'Antonio Jackson', 'MonthlyPurchases': {'2020-03': 16185.3}, 'PreferredBranch': 'Nguyen-Lopez', 'TopProducts': [{'ProductName': 'Evidence', 'Quantity': 20}, {'ProductName': 'Determine', 'Quantity': 1}, {'ProductName': 'List', 'Quantity': 15}], 'TotalOrders': 1, 'TotalSpent': 21878.59}, {'CustomerID': 653, 'CustomerName': 'Gerald Reynolds', 'MonthlyPurchases': {'2024-11': 15057.46}, 'PreferredBranch': 'Garcia, Patterson and Alvarado', 'TopProducts': [{'ProductName': 'Yourself', 'Quantity': 20}, {'ProductName': 'Remain', 'Quantity': 3}, {'ProductName': 'Newspaper', 'Quantity': 11}], 'TotalOrders': 1, 'TotalSpent': 31849.559999999998}, {'CustomerID': 945, 'CustomerName': 'Jessica Mays', 'MonthlyPurchases': {'2024-12': 5982.54}, 'PreferredBranch': 'Schaefer-Dean', 'TopProducts': [{'ProductName': 'Particularly', 'Quantity': 3}], 'TotalOrders': 1, 'TotalSpent': 5982.54}, {'CustomerID': 901, 'CustomerName': 'Tammy Brown', 'MonthlyPurchases': {'2021-06': 2534.0}, 'PreferredBranch': 'Johnson, Smith and Aguilar', 'TopProducts': [{'ProductName': 'Foreign', 'Quantity': 7}], 'TotalOrders': 1, 'TotalSpent': 2534.0}, {'CustomerID': 25, 'CustomerName': 'Phillip Holmes', 'MonthlyPurchases': {'2021-05': 2243.88}, 'PreferredBranch': 'Martinez, Kane and Fleming', 'TopProducts': [{'ProductName': 'Everything', 'Quantity': 9}], 'TotalOrders': 1, 'TotalSpent': 2243.88}, {'CustomerID': 450, 'CustomerName': 'Patrick Salazar', 'MonthlyPurchases': {'2024-03': 18327.01}, 'PreferredBranch': 'Schmidt-Holt', 'TopProducts': [{'ProductName': 'Outside', 'Quantity': 11}, {'ProductName': 'Deep', 'Quantity': 13}], 'TotalOrders': 1, 'TotalSpent': 23628.239999999998}, {'CustomerID': 915, 'CustomerName': 'Dave White', 'MonthlyPurchases': {'2020-08': 5232.08}, 'PreferredBranch': 'Hayes-Tanner', 'TopProducts': [{'ProductName': 'Base', 'Quantity': 5}, {'ProductName': 'Why', 'Quantity': 5}, {'ProductName': 'Travel', 'Quantity': 14}], 'TotalOrders': 1, 'TotalSpent': 14674.38}, {'CustomerID': 430, 'CustomerName': 'Amanda Huber', 'MonthlyPurchases': {'2020-06': 12727.1}, 'PreferredBranch': 'Thornton LLC', 'TopProducts': [{'ProductName': 'Letter', 'Quantity': 10}], 'TotalOrders': 1, 'TotalSpent': 12727.1}, {'CustomerID': 533, 'CustomerName': 'Ryan Hunter', 'MonthlyPurchases': {'2022-07': 15051.6}, 'PreferredBranch': 'Nguyen-Lopez', 'TopProducts': [{'ProductName': 'Ten', 'Quantity': 11}, {'ProductName': 'Market', 'Quantity': 9}], 'TotalOrders': 1, 'TotalSpent': 23562.08}, {'CustomerID': 754, 'CustomerName': 'Laura Fischer', 'MonthlyPurchases': {'2022-11': 617.43}, 'PreferredBranch': 'Price-Norman', 'TopProducts': [{'ProductName': 'Message', 'Quantity': 1}], 'TotalOrders': 1, 'TotalSpent': 617.43}, {'CustomerID': 600, 'CustomerName': 'Jennifer Hamilton', 'MonthlyPurchases': {'2020-09': 4465.68}, 'PreferredBranch': 'Mason-Hawkins', 'TopProducts': [{'ProductName': 'Himself', 'Quantity': 4}], 'TotalOrders': 1, 'TotalSpent': 4465.68}, {'CustomerID': 338, 'CustomerName': 'Valerie Martin', 'MonthlyPurchases': {'2021-04': 4353.15}, 'PreferredBranch': 'Johnson, Smith and Aguilar', 'TopProducts': [{'ProductName': 'Where', 'Quantity': 8}, {'ProductName': 'Probably', 'Quantity': 9}, {'ProductName': 'Open', 'Quantity': 5}], 'TotalOrders': 1, 'TotalSpent': 15048.07}, {'CustomerID': 653, 'CustomerName': 'Gerald Reynolds', 'MonthlyPurchases': {'2025-01': 9595.0}, 'PreferredBranch': 'Mayo Inc', 'TopProducts': [{'ProductName': 'Take', 'Quantity': 19}], 'TotalOrders': 1, 'TotalSpent': 9595.0}, {'CustomerID': 972, 'CustomerName': 'Andrew Willis', 'MonthlyPurchases': {'2022-03': 1228.14}, 'PreferredBranch': 'Montgomery-Foley', 'TopProducts': [{'ProductName': 'Owner', 'Quantity': 13}, {'ProductName': 'When', 'Quantity': 1}], 'TotalOrders': 1, 'TotalSpent': 2418.42}, {'CustomerID': 396, 'CustomerName': 'Maria Pope', 'MonthlyPurchases': {'2025-01': 3991.44}, 'PreferredBranch': 'Krause, Haas and Lozano', 'TopProducts': [{'ProductName': 'Team', 'Quantity' ...
# Status Code: 200
# Response: []
# Status Code: 200
# Response: [{'BranchName': 'Adams, Mccarthy and Bishop', 'ProductName': 'Mean', 'TotalQuantity': 19, 'TotalRevenue': 16211.56}, {'BranchName': 'Alvarez-Spencer', 'ProductName': 'Gun', 'TotalQuantity': 9, 'TotalRevenue': 6663.69}, {'BranchName': 'Anderson, Roberts and Howard', 'ProductName': 'Treatment', 'TotalQuantity': 16, 'TotalRevenue': 8925.92}, {'BranchName': 'Anderson-Robinson', 'ProductName': 'Central', 'TotalQuantity': 8, 'TotalRevenue': 8040.56}, {'BranchName': 'Anderson-Robinson', 'ProductName': 'Money', 'TotalQuantity': 4, 'TotalRevenue': 7806.28}, {'BranchName': 'Andrews Inc', 'ProductName': 'Tax', 'TotalQuantity': 1, 'TotalRevenue': 1032.71}, {'BranchName': 'Armstrong, Morgan and Gomez', 'ProductName': 'Chance', 'TotalQuantity': 19, 'TotalRevenue': 757.53}, {'BranchName': 'Armstrong, Morgan and Gomez', 'ProductName': 'Capital', 'TotalQuantity': 8, 'TotalRevenue': 15896.72}, {'BranchName': 'Armstrong, Ramos and George', 'ProductName': 'Difficult', 'TotalQuantity': 16, 'TotalRevenue': 4401.44}, {'BranchName': 'Austin, Lutz and Ortiz', 'ProductName': 'One', 'TotalQuantity': 17,
ductName': 'Customer', 'TotalQuantity': 4}, {'BranchName': 'Avila-Coleman', 'ProductName': 'Lose', 'TotalQuantity': 7}, {'BranchName': 'Avila-Coleman', 'ProductName': 'Today', 'TotalQuantity': 4}, {'BranchName': 'Bailey LLC', 'ProductName': 'Mother', 'TotalQuantity': 16}, {'BranchName': 'Bailey-Hayden', 'ProductName': 'Concern', 'TotalQuantity': 15}, {'BranchName': 'Bailey-Wood', 'ProductName': 'Movie', 'TotalQuantity': 18}, {'BranchName': 'Bailey-Wood', 'ProductName': 'Report', 'TotalQuantity': 17}, {'BranchName': 'Bailey-Wood', 'ProductName': 'Tv', 'TotalQuantity': 6}, {'BranchName': 'Baker, Reese and Tucker', 'ProductName': 'Big', 'TotalQuantity': 9}, {'BranchName': 'Barker-Walker', 'ProductName': 'Information', 'TotalQuantity': 19}, {'BranchName': 'Bass, Howell and Hughes', 'ProductName': 'Raise', 'TotalQuantity': 6}, {'BranchName': 'Bass, Howell and Hughes', 'ProductName': 'Since', 'TotalQuantity': 1}, {'BranchName': 'Beck, Malone and Schmidt', 'ProductName': 'Sister', 'TotalQuantity': 12}, {'BranchName': 'Beck, Malone and Schmidt', 'ProductName': 'Visit', 'TotalQuantity': 2}, {'BranchName': 'Bell, Smith and Walsh', 'ProductName': 'Recent', 'TotalQuantity': 11}, {'BranchName': 'Bennett PLC', 'ProductName': 'New', 'TotalQuantity': 18}, {'BranchName': 'Bennett PLC', 'ProductName': 'Such', 'TotalQuantity': 11}, {'BranchName': 'Bennett PLC', 'ProductName': 'Team', 'TotalQuantity': 7}, {'BranchName': 'Bennett, Barber and West', 'ProductName': 'Guy', 'TotalQuantity': 1}, {'BranchName': 'Berry, Avila and Fox', 'ProductName': 'Guy', 'TotalQuantity': 20}, {'BranchName': 'Berry, Avila and Fox', 'ProductName': 'Marriage', 'TotalQuantity': 13}, {'BranchName': 'Bishop, May and Powell', 'ProductName': 'The', 'TotalQuantity': 14}, {'BranchName': 'Bishop, May and Powell', 'ProductName': 'Among', 'TotalQuantity': 9}, {'BranchName': 'Blackburn, Coleman and Cox', 'ProductName': 'House', 'TotalQuantity': 11}, {'BranchName': 'Blackburn, Coleman and Cox', 'ProductName': 'Who', 'TotalQuantity': 10}, {'BranchName': 'Blackburn, Coleman and Cox', 'ProductName': 'Throughout', 'TotalQuantity': 1}, {'BranchName': 'Blanchard-Brown', 'ProductName': 'Experience', 'TotalQuantity': 10}, {'BranchName': 'Bond Group', 'ProductName': 'Receive', 'TotalQuantity': 17}, {'BranchName': 'Bowman and Sons', 'ProductName': 'Old', 'TotalQuantity': 2}, {'BranchName': 'Boyle LLC', 'ProductName': 'Home', 'TotalQuantity': 14}, {'BranchName': 'Boyle LLC', 'ProductName': 'Commercial', 'TotalQuantity': 6}, {'BranchName': 'Brandt-Davis', 'ProductName': 'Computer', 'TotalQuantity': 19}, {'BranchName': 'Brandt-Davis', 'ProductName': 'Write', 'TotalQuantity': 13}, {'BranchName': 'Bran ...
